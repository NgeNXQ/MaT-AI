# %% [markdown]
# ## Лабораторна робота № 1

# %% [markdown]
# ### ІП-14 Бабіч Денис

# %% [markdown]
# #### Підготовчий етап

# %% [markdown]
# ##### Імпортування модулів

# %%
import numpy as np
import skfuzzy as fuzz
import matplotlib.pyplot as plt

# %% [markdown]
# ##### Допоміжна функція

# %%
def build_plot(x_values: np.ndarray, *y_values: np.ndarray, title: str = "", ) -> None:
    plt.grid(True)
    plt.title(title)

    for y_axis in y_values:
        plt.plot(x_values, y_axis)

    plt.show()

# %% [markdown]
# #### 1. Побудувати трикутну і трапецієподібну функцію приналежності.

# %% [markdown]
# ##### Побудова трикутної функції приналежності

# %%
x_values = np.arange(-15, 17, 1)
y_values = fuzz.trimf(x_values, [-3, 0, 3])
build_plot(x_values, y_values, title = "Трикутна функція приналежності")

# %% [markdown]
# ##### Побудова трапецієподібної фукнції приналежності

# %%
x_values = np.arange(-15, 17, 1)
y_values = fuzz.trapmf(x_values, [-3, -1, 6, 9])
build_plot(x_values, y_values, title = "Трапецієподібна функція приналежності")

# %% [markdown]
# #### 2. Побудувати просту і двосторонню функцію приналежності Гаусса, утворену за допомогою різних функцій розподілу.

# %% [markdown]
# ##### Побудова простої функції приналежності Гаусса

# %%
x_values = np.arange(-25, 25, 1)
y_values = fuzz.gaussmf(x_values, 6, 5)
build_plot(x_values, y_values, title = "Проста функція приналежності Гаусса")

# %% [markdown]
# ##### Побудова двосторонньої функції приналежності Гаусса

# %%
x_values = np.arange(-40, 40, 1)
y_values_1 = fuzz.gauss2mf(x_values, 3, 4, 7, 6)
y_values_2 = fuzz.gauss2mf(x_values, 4, 4, 8, 6)
y_values_3 = fuzz.gauss2mf(x_values, 3, 5, 9, 6)
build_plot(x_values, y_values_1, y_values_2, y_values_3, title = "Двостороння функція приналежності Гаусса")

# %% [markdown]
# #### 3. Побудувати функцію приналежності "узагальнений дзвін", яка дозволяє представляти нечіткі суб'єктивні переваги.

# %%
x_values = np.arange(-20, 20, 1)
y_values = fuzz.gbellmf(x_values, 4, 5, 5)
build_plot(x_values, y_values, title = "Функція приналежності \"Узагальнений дзвін\"")

# %% [markdown]
# #### 4. Побудувати набір сігмоїдних функцій: основну односторонню, яка відкрита зліва чи справа; додаткову двосторонню; додаткову несиметричну.

# %% [markdown]
# ##### Сигмоїдна функція - основна одностороння, яка відкрита зліва чи справа

# %%
x_values = np.arange(0, 11, 0.1)
y_values = fuzz.sigmf(x_values, 5, 6)
build_plot(x_values, y_values, title = "Сигмоїдна функція")

# %% [markdown]
# ##### Сигмоїдна функція - додаткова двостороння

# %%
x_values = np.arange(0, 11, 0.1)
y_values = fuzz.dsigmf(x_values, 6, 7, 8, 11)
build_plot(x_values, y_values, title = "Додаткова двостороння сигмоїдна функція")

# %% [markdown]
# ##### Сигмоїдна функція - додаткова несиметрична

# %%
x_values = np.arange(0, 11, 0.1)
y_values = fuzz.psigmf(x_values, 6, 7, 8, 11)
build_plot(x_values, y_values, title = "Додаткова несиметрична сигмоїдна функція")

# %% [markdown]
# #### 5. Побудувати набір поліноміальних функцій приналежності (Z-, PI- і S-функцій).

# %% [markdown]
# ##### Z-функція

# %%
x_values = np.arange(0, 11, 0.1)
y_values = fuzz.zmf(x_values, 3, 5)
build_plot(x_values, y_values, title = "Z-функція")

# %% [markdown]
# ##### Pi-функція

# %%
x_values = np.arange(0, 11, 0.1)
y_values = fuzz.pimf(x_values, 2, 4, 5, 8)
build_plot(x_values, y_values, title = "Pi-функція")

# %% [markdown]
# ##### S-функція

# %%
x_values = np.arange(0, 11, 0.1)
y_values = fuzz.smf(x_values, 3, 5)
build_plot(x_values, y_values, title = "S-функція")

# %% [markdown]
# #### 6. Побудувати мінімаксну інтерпретацію логічних операторів з використанням операцій пошуку мінімуму і максимуму.

# %% [markdown]
# ##### Логічна мінімаксна інтерпретація з використанням операції пошуку мінімуму

# %%
x_values = np.arange(-20, 20, 1)

function_1 = fuzz.gaussmf(x_values, 1, 4)
function_2 = fuzz.gaussmf(x_values, 5, 4)
function_min = np.fmin(function_1, function_2)

build_plot(x_values, function_1, function_2, function_min, title = "Інтерпретація з використанням пошуку мінімуму")

# %% [markdown]
# ##### Логічна мінімаксна інтерпретація з використанням операції пошуку максимуму

# %%
x_values = np.arange(-20, 20, 1)

function_1 = fuzz.gaussmf(x_values, 1, 4)
function_2 = fuzz.gaussmf(x_values, 5, 4)
function_max = np.fmax(function_1, function_2)

build_plot(x_values, function_1, function_2, function_max, title = "Інтерпретація з використанням пошуку максимуму")

# %% [markdown]
# #### 7. Побудувати вірогідну інтерпретацію кон'юнктивну і диз'юнктивних операторів.

# %% [markdown]
# ##### Інтерпретація кон'юнктивних операторів

# %%
x_values = np.arange(-20, 25, 1)

function_1 = fuzz.gaussmf(x_values, 1, 4)
function_2 = fuzz.gaussmf(x_values, 5, 4)
function_min = function_1 * function_2

build_plot(x_values, function_1, function_2, function_min, title = "Інтерпретація кон'юнктивних операторів")

# %% [markdown]
# ##### Інтерпретація диз'юнктивних операторів

# %%
x_values = np.arange(-20, 25, 1)

function_1 = fuzz.gaussmf(x_values, 1, 4)
function_2 = fuzz.gaussmf(x_values, 5, 4)
function_min = function_1 + function_2 - function_1 * function_2

build_plot(x_values, function_1, function_2, function_min, title = "Інтерпретація кон'юнктивних операторів")

# %% [markdown]
# #### 8. Побудувати доповнення нечіткої множини, яке описує деяке розмите судження і представляє собою математичний опис вербального вираження, який заперечує це нечітка множина.

# %%
x_values = np.arange(-20, 20, 1)
y_values = fuzz.gaussmf(x_values, 2, 4)
build_plot(x_values, y_values, 1 - y_values, title = "Графік різниці")
