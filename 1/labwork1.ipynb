# %% [markdown]
# ## Лабораторна робота № 1

# %% [markdown]
# ### ІП-14 Бабіч Денис

# %% [markdown]
# #### Підготовчий етап

# %% [markdown]
# ##### Імпортування модулів

# %%
import numpy as np
import skfuzzy as fuzz
import matplotlib.pyplot as plt

# %% [markdown]
# ##### Допоміжна функція

# %%
def build_plot(*plot_arguments: dict, title: str = None) -> None:
    plt.grid(True)
    plt.title(title)

    for data in plot_arguments:
        label = data.get("label", None)
        color = data.get("color", "black")
        x_values = data.get("x_values", [])
        y_values = data.get("y_values", [])
        linestyle = data.get("linestyle", None)
        
        plt.plot(x_values, y_values, color = color, linestyle = linestyle, label = label)

        if label is not None:
            plt.legend(loc = "upper right")

    plt.show()

# %% [markdown]
# #### 1. Побудувати трикутну і трапецієподібну функцію приналежності.

# %% [markdown]
# ##### Побудова трикутної функції приналежності

# %%
x_values = np.arange(-15, 17, 1)
y_values = fuzz.trimf(x_values, [-3, 0, 3])

plot_arguments = { "x_values": x_values, 
                   "y_values": y_values }

build_plot(plot_arguments, title = "Трикутна функція приналежності")

# %% [markdown]
# ##### Побудова трапецієподібної фукнції приналежності

# %%
x_values = np.arange(-15, 17, 1)
y_values = fuzz.trapmf(x_values, [-3, -1, 6, 9])

plot_arguments = { "x_values": x_values, 
                   "y_values": y_values }

build_plot(plot_arguments, title = "Трапецієподібна функція приналежності")

# %% [markdown]
# #### 2. Побудувати просту і двосторонню функцію приналежності Гаусса, утворену за допомогою різних функцій розподілу.

# %% [markdown]
# ##### Побудова простої функції приналежності Гаусса

# %%
x_values = np.arange(-15, 25, 1)
y_values = fuzz.gaussmf(x_values, 5, 4)

plot_arguments = { "x_values": x_values,
                   "y_values": y_values }

build_plot(plot_arguments, title = "Проста функція приналежності Гаусса")

# %% [markdown]
# ##### Побудова двосторонньої функції приналежності Гаусса

# %%
x_values = np.arange(-15, 25, 1)
y_values_1 = fuzz.gauss2mf(x_values, 1, 3, 3, 3)
y_values_2 = fuzz.gauss2mf(x_values, 2, 4, 4, 4)
y_values_3 = fuzz.gauss2mf(x_values, 3, 5, 5, 5)

plot_arguments_1 = { "x_values": x_values, 
                     "y_values": y_values_1,
                     "color": 'r',
                     "label": f"Гаусса {1, 3, 3, 3}" }

plot_arguments_2 = { "x_values": x_values, 
                     "y_values": y_values_2,
                     "color": 'g',
                     "label": f"Гаусса {2, 4, 4, 4}" }

plot_arguments_3 = { "x_values": x_values, 
                     "y_values": y_values_3,
                     "color": 'b',
                     "label": f"Гаусса {3, 5, 5, 5}" }

build_plot(plot_arguments_1, plot_arguments_2, plot_arguments_3, title = "Двостороння функція приналежності Гаусса")

# %% [markdown]
# #### 3. Побудувати функцію приналежності "узагальнений дзвін", яка дозволяє представляти нечіткі суб'єктивні переваги.

# %%
x_values = np.arange(-20, 25, 1)
y_values = fuzz.gbellmf(x_values, 5, 4, 3)

plot_arguments = { "x_values": x_values,
                   "y_values": y_values }

build_plot(plot_arguments, title = "Функція приналежності \"Узагальнений дзвін\"")

# %% [markdown]
# #### 4. Побудувати набір сігмоїдних функцій: основну односторонню, яка відкрита зліва чи справа; додаткову двосторонню; додаткову несиметричну.

# %% [markdown]
# ##### Сігмоїдна функція - основна одностороння, яка відкрита зліва чи справа

# %%
x_values = np.arange(0.5, 8, 0.01)
y_values = fuzz.sigmf(x_values, 4, 6)

plot_arguments = { "x_values": x_values,
                   "y_values": y_values }

build_plot(plot_arguments, title = "Основна одностороння сігмоїдна функція")

# %% [markdown]
# ##### Сігмоїдна функція - додаткова двостороння

# %%
x_values = np.arange(0.5, 8, 0.01)
y_values = fuzz.dsigmf(x_values, 3, 5, 6, 5)

plot_arguments = { "x_values": x_values,
                   "y_values": y_values }

build_plot(plot_arguments, title = "Додаткова двостороння сігмоїдна функція")

# %% [markdown]
# ##### Сігмоїдна функція - додаткова несиметрична

# %%
x_values = np.arange(0.5, 8, 0.01)
y_values = fuzz.psigmf(x_values, 3, 5, 6, 5)

plot_arguments = { "x_values": x_values, 
                   "y_values": y_values }

build_plot(plot_arguments, title = "Додаткова несиметрична сігмоїдна функція")

# %% [markdown]
# #### 5. Побудувати набір поліноміальних функцій приналежності (Z-, PI- і S-функцій).

# %% [markdown]
# ##### Z-функція

# %%
x_values = np.arange(0.5, 8, 0.01)
y_values = fuzz.zmf(x_values, 4, 5)

plot_arguments = { "x_values": x_values,
                   "y_values": y_values }

build_plot(plot_arguments, title = "Z-функція")

# %% [markdown]
# ##### PI-функція

# %%
x_values = np.arange(0.5, 8, 0.01)
y_values = fuzz.pimf(x_values, 2, 4, 5, 7)

plot_arguments = { "x_values": x_values,
                   "y_values": y_values }

build_plot(plot_arguments, title = "PI-функція")

# %% [markdown]
# ##### S-функція

# %%
x_values = np.arange(0.5, 8, 0.01)
y_values = fuzz.smf(x_values, 4, 5)

plot_arguments = { "x_values": x_values, 
                   "y_values": y_values }

build_plot(plot_arguments, title = "S-функція")

# %% [markdown]
# #### 6. Побудувати мінімаксну інтерпретацію логічних операторів з використанням операцій пошуку мінімуму і максимуму.

# %% [markdown]
# ##### Логічна мінімаксна інтерпретація з використанням операції пошуку мінімуму

# %%
x_values = np.arange(-9, 15, 1)
y_values_1 = fuzz.gaussmf(x_values, 1, 4)
y_values_2 = fuzz.gaussmf(x_values, 5, 4)
min_function = np.fmin(y_values_1, y_values_2)

plot_arguments_1 = { "x_values": x_values,
                     "y_values": y_values_1,
                     "linestyle": '--' }

plot_arguments_2 = { "x_values": x_values,
                     "y_values": y_values_2,
                     "linestyle": '--' }

plot_arguments_3 = { "x_values": x_values,
                     "y_values": min_function,
                     "color": 'r',
                     "label": "Мінімум" }

build_plot(plot_arguments_1, plot_arguments_2, plot_arguments_3, title = "Інтерпретація з використанням пошуку мінімуму")

# %% [markdown]
# ##### Логічна мінімаксна інтерпретація з використанням операції пошуку максимуму

# %%
x_values = np.arange(-9, 15, 1)
y_values_1 = fuzz.gaussmf(x_values, 1, 4)
y_values_2 = fuzz.gaussmf(x_values, 5, 4)
max_function = np.fmax(y_values_1, y_values_2)

plot_arguments_1 = { "x_values": x_values,
                     "y_values": y_values_1,
                     "linestyle": '--' }

plot_arguments_2 = { "x_values": x_values,
                     "y_values": y_values_2,
                     "linestyle": '--' }

plot_arguments_3 = { "x_values": x_values,
                     "y_values": max_function,
                     "color": 'r',
                     "label": "Максимум" }

build_plot(plot_arguments_1, plot_arguments_2, plot_arguments_3, title = "Інтерпретація з використанням пошуку максимуму")

# %% [markdown]
# #### 7. Побудувати вірогідну інтерпретацію кон'юнктивну і диз'юнктивних операторів.

# %% [markdown]
# ##### Інтерпретація кон'юнктивних операторів

# %%
x_values = np.arange(-9, 15, 1)
y_values_1 = fuzz.gaussmf(x_values, 1, 4)
y_values_2 = fuzz.gaussmf(x_values, 5, 4)
result = y_values_1 * y_values_2

plot_arguments_1 = { "x_values": x_values,
                     "y_values": y_values_1,
                     "color": 'b',
                     "label": 'A' }

plot_arguments_2 = { "x_values": x_values,
                     "y_values": y_values_2,
                     "color": 'g',
                     "label": 'B' }

plot_arguments_3 = { "x_values": x_values,
                   "y_values": result,
                   "linestyle": '--',
                   "color": 'r',
                   "label": "AND: A ^ B" }

build_plot(plot_arguments_1, plot_arguments_2, plot_arguments_3, title = "Інтерпретація кон'юнктивних операторів")

# %% [markdown]
# ##### Інтерпретація диз'юнктивних операторів

# %%
x_values = np.arange(-9, 15, 1)
y_values_1 = fuzz.gaussmf(x_values, 1, 4)
y_values_2 = fuzz.gaussmf(x_values, 5, 4)
result = y_values_1 + y_values_2 - y_values_1

plot_arguments_1 = { "x_values": x_values,
                     "y_values": y_values_1,
                     "color": 'g',
                     "label": 'A' }

plot_arguments_2 = { "x_values": x_values,
                     "y_values": y_values_2,
                     "color": 'b',
                     "label": 'B' }

plot_arguments_3 = { "x_values": x_values,
                     "y_values": result,
                     "linestyle": '--',
                     "color": 'r',
                     "label": "OR: A v B v ∼A = B " }

build_plot(plot_arguments_1, plot_arguments_2, plot_arguments_3, title = "Інтерпретація диз'юнктивних операторів")

# %% [markdown]
# #### 8. Побудувати доповнення нечіткої множини, яке описує деяке розмите судження і представляє собою математичний опис вербального вираження, який заперечує це нечітка множина.

# %%
x_values = np.arange(-9, 15, 1)
y_values = fuzz.gaussmf(x_values, 2, 4)

plot_arguments_1 = { "x_values": x_values,
                     "y_values": y_values,
                     "color": 'g',
                     "label": "Стандартна" }

plot_arguments_2 = { "x_values": x_values,
                     "y_values": 1 - y_values,
                     "color": 'r',
                     "label": "NOT" }

build_plot(plot_arguments_1, plot_arguments_2, title = "Графік різниці")
